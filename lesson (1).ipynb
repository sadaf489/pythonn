# %%
#data types
#1.numeric
#a.integer:654,-43
#b.float:7.6,4.6
#c.complex:43+5j
var_int=231
print(var_int)
print (type(var_int))
# Out:
# 231
# <class 'int'>

# %%
var_float=45.7
print(var_float)
print(type(var_float))
# Out:
# 45.7
# <class 'float'>

# %%
var_str="43"
print(var_str)
print(type(var_str))
# Out:
# 43
# <class 'str'>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-135523d12b00> in <cell line: 2>()
#       1 age=range(5)
# ----> 2 print(age)
#       3 print(type(age))
#
# TypeError: 'list' object is not callable
